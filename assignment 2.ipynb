# %%
greeting = 'Hello'
a = input("Enter Any Country : ")
c = greetings + ' welcome to ' + a
print(c)
a = "India"
c = greetings + ' welcome to ' + a
print(c)
# Out:
# Enter Any Country : pakistan
# Hello welcome to pakistan
# Hello welcome to India
