# %%
a = input ("Enter your Name : ")
b = input ("Enter Your Father Name : ")
c = input ("Enter Your Registration Number : ")
d = input ("Enter Your Programming fundamentals Marks : ")
e = input ("Enter Your ICT Marks : ")
f = input ("Enter Your Calculus marks : ")
g = input ("Enter Your Physics marks : ")
c = int (c)
d = int (d)
e = int (e)
f = int (f)
g = int (g)
print ("\n")
print ("Name :" , a)
print ("Father Name :" , b)
print ("Registration Number :", c)
print ("Programming Marks :" , d)
print ("ICT Marks :" , e)
print ("Calculus Marks :" , f)
print ("Physics Marks :" , g)
print ("Total Marks :" , d + e + f + g)
print ("Percentage :" , ( (d + e + f + g) * 100 ) / 400)
# Out:
# Enter your Name : Hashir
# Enter Your Father Name : GM
# Enter Your Registration Number : 122
# Enter Your Programming fundamentals Marks : 88
# Enter Your ICT Marks : 66
# Enter Your Calculus marks : 77
# Enter Your Physics marks : 90
#
#
# Name : Hashir
# Father Name : GM
# Registration Number : 122
# Programming Marks : 88
# ICT Marks : 66
# Calculus Marks : 77
# Physics Marks : 90
# Total Marks : 321
# Percentage : 80.25
