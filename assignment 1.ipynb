# %%
a = input("Enter Number 1 : ")
b = input("Enter Number 2 : ")
a = int(a)
b = int(b)
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# Enter Number 1 : 12
# Enter Number 2 : 2
# 14
# 10
# 24
# 6.0
